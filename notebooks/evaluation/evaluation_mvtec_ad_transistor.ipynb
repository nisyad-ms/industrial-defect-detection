# %%
import os
import json

# %%
dataset_name = "mvtec_ad_bottle"

dataset_coco = f"/home/nisyad/projects/industrial-defect-detection/datasets/processed/{dataset_name}/test.json"

# Zero-shot responses
responses = f"/home/nisyad/projects/industrial-defect-detection/{dataset_name}_responses.json"

# 1-shot In-context responses
# responses = f"/home/nisyad/projects/industrial-defect-detection/{dataset_name}_responses_in_context.json"

# %%
with open(dataset_coco, "r") as f:
    coco = json.load(f)
    
categories = coco["categories"]
categories
# Out:
# [{'id': 1, 'name': 'good'},
#  {'id': 2, 'name': 'broken'},
#  {'id': 3, 'name': 'contamination'}]

# %%
with open(responses, "r") as f:
    results = json.load(f)
    
results[:3]
# Out:
# [{'sample_idx': 0,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The bottle has contamination on its inside surface.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.0, 0.2, 0.2, 0.5]"\n}\n```',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle has contamination on its inside surface.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.0, 0.2, 0.2, 0.5]'}},
#  {'sample_idx': 1,
#   'response': '```json\n{\n  "is_defective": "no",\n  "reason": "",\n  "defect_type": "",\n  "bounding_box": ""\n}\n```',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'no',
#    'reason': '',
#    'defect_type': '',
#    'bounding_box': ''}},
#  {'sample_idx': 2,
#   'response': '{\n    "is_defective": "no",\n    "reason": "",\n    "defect_type": "",\n    "bounding_box": ""\n}',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'no',
#    'reason': '',
#    'defect_type': '',
#    'bounding_box': ''}}]

# %%
is_defective_types = set()
is_defective_count = {"yes": 0, "no": 0, "other": 0}

for result in results:
    is_defective_type = result["parsed_response"]["is_defective"]
    if is_defective_type not in is_defective_count:
        is_defective_count["other"] += 1
    else:
        is_defective_count[is_defective_type] += 1
    is_defective_types.add(is_defective_type)
    

is_defective_types
print(is_defective_count)
# Out:
# {'yes': 74, 'no': 9, 'other': 0}

# %%
defect_types = set()

for result in results:
    defect_type = result["parsed_response"]["defect_type"]
    defect_types.add(defect_type)

defect_types
# Out:
# {'', 'broken', 'contamination'}

# %%
defect_types = list(defect_types)
defect_types
# Out:
# ['contamination', '', 'broken']

# %%
# Split multiple defect types
defect_types = [defect_type.split(", ") for defect_type in defect_types]
defect_types
# Out:
# [['contamination'], [''], ['broken']]

# %%
def calculate_iou(box1, box2):
    """
    Calculate the Intersection over Union (IoU) of two bounding boxes.

    Parameters:
    - box1, box2: Lists of 4 coordinates [x_top, y_top, x_bottom, y_bottom].

    Returns:
    - IoU as a float value.
    """
    # Unpack the coordinates
    x1_top, y1_top, x1_bottom, y1_bottom = box1
    x2_top, y2_top, x2_bottom, y2_bottom = box2

    # Calculate the (x, y)-coordinates of the intersection rectangle
    x_inter_top = max(x1_top, x2_top)
    y_inter_top = max(y1_top, y2_top)
    x_inter_bottom = min(x1_bottom, x2_bottom)
    y_inter_bottom = min(y1_bottom, y2_bottom)

    # Compute the area of intersection rectangle
    inter_area = max(0, x_inter_bottom - x_inter_top) * max(0, y_inter_bottom - y_inter_top)

    # Compute the area of both the prediction and ground-truth rectangles
    box1_area = (x1_bottom - x1_top) * (y1_bottom - y1_top)
    box2_area = (x2_bottom - x2_top) * (y2_bottom - y2_top)

    # Compute the intersection over union by taking the intersection
    # area and dividing it by the sum of prediction + ground-truth
    # areas - the interesection area
    iou = inter_area / float(box1_area + box2_area - inter_area)

    return iou

# %%
# Calculate the mean IoU

total_iou = 0

for result in results:
    is_defective = result["parsed_response"]["is_defective"]
    target = result["target"][0][0]
     
    if (is_defective == "yes" and target != 0):
        tgt_bbox = result["target"][0][1:]
        pred_bbox = result["parsed_response"]["bounding_box"]
        
        try:
            pred_bbox = json.loads(pred_bbox) if not isinstance(pred_bbox, list) else pred_bbox
        except:
            pred_bbox = [0, 0, 0, 0]
        iou = calculate_iou(tgt_bbox, pred_bbox)
        total_iou += iou
        
    if (is_defective == "no" and target == 0):
        total_iou += 1
    
mean_iou = total_iou / len(results)
print(mean_iou)
# Out:
# 0.2179461145830379

# %%
def calculate_binary_accuracy(responses):
    not_defective_correct = 0
    defective_correct = 0
    for item in responses:
        response = item["parsed_response"]
        target = item["target"][0][0]
        
        # print(response["is_defective"], target)
        
        if target == 0 and response["is_defective"] == "no":
            not_defective_correct += 1
            # print("non defective correct: ", not_defective_correct)
        elif target != 0.0 and response["is_defective"] == "yes":
            defective_correct += 1
            # print("defective correct: ", defective_correct)
            
    print(not_defective_correct, defective_correct)
    return (not_defective_correct + defective_correct )/ len(responses)


print(len(results))
calculate_binary_accuracy(results)
# Out:
# 83
# 6 60
# 0.7951807228915663

# %%
results
# Out:
# [{'sample_idx': 0,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The bottle has contamination on its inside surface.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.0, 0.2, 0.2, 0.5]"\n}\n```',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle has contamination on its inside surface.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.0, 0.2, 0.2, 0.5]'}},
#  {'sample_idx': 1,
#   'response': '```json\n{\n  "is_defective": "no",\n  "reason": "",\n  "defect_type": "",\n  "bounding_box": ""\n}\n```',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'no',
#    'reason': '',
#    'defect_type': '',
#    'bounding_box': ''}},
#  {'sample_idx': 2,
#   'response': '{\n    "is_defective": "no",\n    "reason": "",\n    "defect_type": "",\n    "bounding_box": ""\n}',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'no',
#    'reason': '',
#    'defect_type': '',
#    'bounding_box': ''}},
#  {'sample_idx': 3,
#   'response': '```json\n{\n  "is_defective": "no",\n  "reason": "",\n  "defect_type": "",\n  "bounding_box": ""\n}\n```',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'no',
#    'reason': '',
#    'defect_type': '',
#    'bounding_box': ''}},
#  {'sample_idx': 4,
#   'response': '{\n  "is_defective": "yes",\n  "reason": "There is noticeable contamination inside the bottle visible near the edge on the bottom left side.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.1, 0.8, 0.2, 0.9]"\n}',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is noticeable contamination inside the bottle visible near the edge on the bottom left side.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.1, 0.8, 0.2, 0.9]'}},
#  {'sample_idx': 5,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "There is visible contamination on the inner rim of the bottle.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.35, 0.10, 0.85, 0.40]"\n}\n```',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is visible contamination on the inner rim of the bottle.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.35, 0.10, 0.85, 0.40]'}},
#  {'sample_idx': 6,
#   'response': '{\n  "is_defective": "yes",\n  "reason": "There is contamination visible around the inner rim of the glass bottle.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.15, 0.15, 0.85, 0.40]"\n}',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is contamination visible around the inner rim of the glass bottle.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.15, 0.15, 0.85, 0.40]'}},
#  {'sample_idx': 7,
#   'response': '{\n   "is_defective": "yes",\n   "reason": "There is a noticeable crack on the inner edge of the bottle.",\n   "defect_type": "broken",\n   "bounding_box": "[0.42, 0.67, 0.58, 0.77]"\n}',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a noticeable crack on the inner edge of the bottle.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.42, 0.67, 0.58, 0.77]'}},
#  {'sample_idx': 8,
#   'response': '{\n"is_defective": "yes",\n"reason": "There appears to be a contamination inside the bottle visible as irregularities and residues.",\n"defect_type": "contamination",\n"bounding_box": "[0.1, 0.2, 0.9, 0.8]"\n}',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There appears to be a contamination inside the bottle visible as irregularities and residues.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.1, 0.2, 0.9, 0.8]'}},
#  {'sample_idx': 9,
#   'response': '{\n    "is_defective": "yes",\n    "reason": "There is contamination on the inner surface of the bottle near the top edge visible as a dark, irregular line.",\n    "defect_type": "contamination",\n    "bounding_box": "[0.2, 0.1, 0.8, 0.2]"\n}',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is contamination on the inner surface of the bottle near the top edge visible as a dark, irregular line.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.2, 0.1, 0.8, 0.2]'}},
#  {'sample_idx': 10,
#   'response': '```json\n{\n    "is_defective": "yes",\n    "reason": "There appears to be contamination along the inner edge of the bottle\'s mouth.",\n    "defect_type": "contamination",\n    "bounding_box": "[0.25, 0.15, 0.75, 0.35]"\n}\n```',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': "There appears to be contamination along the inner edge of the bottle's mouth.",
#    'defect_type': 'contamination',
#    'bounding_box': '[0.25, 0.15, 0.75, 0.35]'}},
#  {'sample_idx': 11,
#   'response': '{\n  "is_defective": "yes",\n  "reason": "There is contamination visible inside the bottle near the top edge.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.4, 0.1, 0.7, 0.2]"\n}',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is contamination visible inside the bottle near the top edge.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.4, 0.1, 0.7, 0.2]'}},
#  {'sample_idx': 12,
#   'response': '{\n  "is_defective": "no",\n  "reason": "",\n  "defect_type": "",\n  "bounding_box": ""\n}',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'no',
#    'reason': '',
#    'defect_type': '',
#    'bounding_box': ''}},
#  {'sample_idx': 13,
#   'response': '{\n  "is_defective": "yes",\n  "reason": "There is visible contamination along the inner rim of the bottle.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.0, 0.19, 1.0, 0.45]"\n}',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is visible contamination along the inner rim of the bottle.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.0, 0.19, 1.0, 0.45]'}},
#  {'sample_idx': 14,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "There is contamination visible along the inner rim of the bottle.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.7, 0.1, 1.0, 0.3]"\n}\n```',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is contamination visible along the inner rim of the bottle.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.7, 0.1, 1.0, 0.3]'}},
#  {'sample_idx': 15,
#   'response': '{\n  "is_defective": "no",\n  "reason": "",\n  "defect_type": "",\n  "bounding_box": ""\n}',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'no',
#    'reason': '',
#    'defect_type': '',
#    'bounding_box': ''}},
#  {'sample_idx': 16,
#   'response': '{\n  "is_defective": "no",\n  "reason": "",\n  "defect_type": "",\n  "bounding_box": ""\n}',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'no',
#    'reason': '',
#    'defect_type': '',
#    'bounding_box': ''}},
#  {'sample_idx': 17,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "There is a visible contamination at the bottom left edge of the bottle.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.05, 0.9, 0.15, 1.0]"\n}\n```',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a visible contamination at the bottom left edge of the bottle.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.05, 0.9, 0.15, 1.0]'}},
#  {'sample_idx': 18,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The bottle shows signs of contamination in the form of orange-brown residue along the inner rim.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.15, 0.15, 0.85, 0.25]"\n}\n```',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle shows signs of contamination in the form of orange-brown residue along the inner rim.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.15, 0.15, 0.85, 0.25]'}},
#  {'sample_idx': 19,
#   'response': '{\n  "is_defective": "yes",\n  "reason": "There is a broken area on the bottle\'s rim.",\n  "defect_type": "broken",\n  "bounding_box": "[0.55, 0.45, 0.7, 0.55]"\n}',
#   'target': [[0.0, -1.0, -1.0, -1.0, -1.0]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': "There is a broken area on the bottle's rim.",
#    'defect_type': 'broken',
#    'bounding_box': '[0.55, 0.45, 0.7, 0.55]'}},
#  {'sample_idx': 20,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The bottle is broken as visible by the jagged and missing pieces along the rim.",\n  "defect_type": "broken",\n  "bounding_box": "[0.6, 0.1, 1.0, 0.7]"\n}\n```',
#   'target': [[1.0,
#     0.20666666328907013,
#     0.17000000178813934,
#     0.8622221946716309,
#     0.8455555438995361]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle is broken as visible by the jagged and missing pieces along the rim.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.6, 0.1, 1.0, 0.7]'}},
#  {'sample_idx': 21,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The bottle has a broken section on the top edge.",\n  "defect_type": "broken",\n  "bounding_box": "[0.35, 0.05, 0.65, 0.3]"\n}\n```',
#   'target': [[1.0,
#     0.14222222566604614,
#     0.19111111760139465,
#     0.6677777767181396,
#     0.8811110854148865]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle has a broken section on the top edge.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.35, 0.05, 0.65, 0.3]'}},
#  {'sample_idx': 22,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The bottle has broken glass pieces at the rim.",\n  "defect_type": "broken",\n  "bounding_box": "[0.7, 0.5, 0.9, 0.8]"\n}\n```',
#   'target': [[1.0,
#     0.4866666793823242,
#     0.23111110925674438,
#     0.8577777743339539,
#     0.8544444441795349]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle has broken glass pieces at the rim.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.7, 0.5, 0.9, 0.8]'}},
#  {'sample_idx': 23,
#   'response': '{\n  "is_defective": "yes",\n  "reason": "The bottle appears to have broken segments around the mouth.",\n  "defect_type": "broken",\n  "bounding_box": "[0.1, 0.1, 0.9, 0.9]"\n}',
#   'target': [[1.0,
#     0.035555556416511536,
#     0.04888888821005821,
#     0.7777777910232544,
#     0.9577777981758118]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle appears to have broken segments around the mouth.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.1, 0.1, 0.9, 0.9]'}},
#  {'sample_idx': 24,
#   'response': '{\n    "is_defective": "yes",\n    "reason": "There is contamination visible inside the neck of the bottle.",\n    "defect_type": "contamination",\n    "bounding_box": "[0.2, 0.7, 0.5, 1.0]"\n}',
#   'target': [[1.0,
#     0.16777777671813965,
#     0.3933333456516266,
#     0.5088889002799988,
#     0.8133333325386047]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is contamination visible inside the neck of the bottle.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.2, 0.7, 0.5, 1.0]'}},
#  {'sample_idx': 25,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The bottle has broken glass near the neck area.",\n  "defect_type": "broken",\n  "bounding_box": "[0.4, 0.1, 0.6, 0.2]"\n}\n```',
#   'target': [[1.0,
#     0.34111112356185913,
#     0.14222222566604614,
#     0.8711110949516296,
#     0.6422222256660461]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle has broken glass near the neck area.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.4, 0.1, 0.6, 0.2]'}},
#  {'sample_idx': 26,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The bottle has a broken area on its rim.",\n  "defect_type": "broken",\n  "bounding_box": "[0.15, 0.1, 0.45, 0.35]"\n}\n```',
#   'target': [[1.0,
#     0.1322222203016281,
#     0.25999999046325684,
#     0.8588888645172119,
#     0.8866666555404663]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle has a broken area on its rim.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.15, 0.1, 0.45, 0.35]'}},
#  {'sample_idx': 27,
#   'response': '{\n  "is_defective": "yes",\n  "reason": "There is contamination present inside the glass bottle.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.6, 0.6, 0.8, 0.8]"\n}',
#   'target': [[1.0,
#     0.1433333307504654,
#     0.43111109733581543,
#     0.8222222328186035,
#     0.8488888740539551]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is contamination present inside the glass bottle.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.6, 0.6, 0.8, 0.8]'}},
#  {'sample_idx': 28,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The glass bottle is broken at the rim.",\n  "defect_type": "broken",\n  "bounding_box": "[0.7, 0.6, 0.9, 0.8]"\n}\n```',
#   'target': [[1.0,
#     0.3888888955116272,
#     0.31555554270744324,
#     0.8566666841506958,
#     0.9111111164093018]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The glass bottle is broken at the rim.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.7, 0.6, 0.9, 0.8]'}},
#  {'sample_idx': 29,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The bottle has contamination near the inner edge.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.4, 0.1, 0.6, 0.3]"\n}\n```',
#   'target': [[1.0,
#     0.1455555558204651,
#     0.1366666704416275,
#     0.7944444417953491,
#     0.7833333611488342]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle has contamination near the inner edge.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.4, 0.1, 0.6, 0.3]'}},
#  {'sample_idx': 30,
#   'response': '{\n  "is_defective": "yes",\n  "reason": "The rim of the bottle appears to be broken.",\n  "defect_type": "broken",\n  "bounding_box": "[0.6, 0.1, 0.95, 0.5]"\n}',
#   'target': [[1.0,
#     0.4233333468437195,
#     0.17555555701255798,
#     0.8766666650772095,
#     0.8733333349227905]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The rim of the bottle appears to be broken.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.6, 0.1, 0.95, 0.5]'}},
#  {'sample_idx': 31,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "There is a noticeable irregularity on the left side of the bottle which looks like a break.",\n  "defect_type": "broken",\n  "bounding_box": "[0.1, 0.25, 0.3, 0.45]"\n}\n```',
#   'target': [[1.0,
#     0.15555556118488312,
#     0.1944444477558136,
#     0.4977777898311615,
#     0.5600000023841858]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a noticeable irregularity on the left side of the bottle which looks like a break.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.1, 0.25, 0.3, 0.45]'}},
#  {'sample_idx': 32,
#   'response': '{\n  "is_defective": "yes",\n  "reason": "The bottle has visible contamination inside, near the edge.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.7, 0.7, 0.9, 0.9]"\n}',
#   'target': [[1.0,
#     0.20444443821907043,
#     0.476666659116745,
#     0.8255555629730225,
#     0.8488888740539551]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle has visible contamination inside, near the edge.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.7, 0.7, 0.9, 0.9]'}},
#  {'sample_idx': 33,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The bottle has a visible broken part near the top edge.",\n  "defect_type": "broken",\n  "bounding_box": "[0.6, 0.1, 0.9, 0.3]"\n}\n```',
#   'target': [[1.0,
#     0.4511111080646515,
#     0.1733333319425583,
#     0.8688889145851135,
#     0.7222222089767456]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle has a visible broken part near the top edge.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.6, 0.1, 0.9, 0.3]'}},
#  {'sample_idx': 34,
#   'response': '{\n    "is_defective": "yes",\n    "reason": "The glass bottle is broken at the top edge.",\n    "defect_type": "broken",\n    "bounding_box": "[0.27, 0.07, 0.73, 0.35]"\n}',
#   'target': [[1.0,
#     0.2588889002799988,
#     0.14444445073604584,
#     0.8422222137451172,
#     0.8177777528762817]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The glass bottle is broken at the top edge.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.27, 0.07, 0.73, 0.35]'}},
#  {'sample_idx': 35,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The glass bottle has a broken section on the rim.",\n  "defect_type": "broken",\n  "bounding_box": "[0.7, 0.1, 0.9, 0.3]"\n}\n```',
#   'target': [[1.0,
#     0.10333333164453506,
#     0.06666667014360428,
#     0.7222222089767456,
#     0.699999988079071]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The glass bottle has a broken section on the rim.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.7, 0.1, 0.9, 0.3]'}},
#  {'sample_idx': 36,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The glass bottle is broken at the rim.",\n  "defect_type": "broken",\n  "bounding_box": "[0.2, 0.2, 0.8, 0.8]"\n}\n```',
#   'target': [[1.0,
#     0.2011111080646515,
#     0.35777777433395386,
#     0.8577777743339539,
#     0.8877778053283691]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The glass bottle is broken at the rim.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.2, 0.2, 0.8, 0.8]'}},
#  {'sample_idx': 37,
#   'response': '{\n    "is_defective": "yes",\n    "reason": "The bottle has a broken section in the rim.",\n    "defect_type": "broken",\n    "bounding_box": "[0.6, 0.1, 0.9, 0.4]"\n}',
#   'target': [[1.0,
#     0.5922222137451172,
#     0.20666666328907013,
#     0.8233333230018616,
#     0.6733333468437195]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle has a broken section in the rim.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.6, 0.1, 0.9, 0.4]'}},
#  {'sample_idx': 38,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The glass bottle is broken at the rim.",\n  "defect_type": "broken",\n  "bounding_box": "[0.35, 0.05, 0.85, 0.25]"\n}\n```',
#   'target': [[1.0,
#     0.14888888597488403,
#     0.1644444465637207,
#     0.5799999833106995,
#     0.8266666531562805]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The glass bottle is broken at the rim.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.35, 0.05, 0.85, 0.25]'}},
#  {'sample_idx': 39,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The glass bottle has visible broken fragments around the rim.",\n  "defect_type": "broken",\n  "bounding_box": "[0.2, 0.2, 0.8, 0.5]"\n}\n```',
#   'target': [[1.0,
#     0.1455555558204651,
#     0.1644444465637207,
#     0.8722222447395325,
#     0.6933333277702332]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The glass bottle has visible broken fragments around the rim.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.2, 0.2, 0.8, 0.5]'}},
#  {'sample_idx': 40,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "There is contamination inside the bottle near the rim.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.42, 0.13, 0.47, 0.2]"\n}\n```',
#   'target': [[2.0,
#     0.28333333134651184,
#     0.2888889014720917,
#     0.7177777886390686,
#     0.7344444394111633]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is contamination inside the bottle near the rim.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.42, 0.13, 0.47, 0.2]'}},
#  {'sample_idx': 41,
#   'response': '{\n  "is_defective": "yes",\n  "reason": "There is a foreign object (contamination) inside the neck of the bottle.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.7, 0.3, 1.0, 0.6]"\n}',
#   'target': [[2.0,
#     0.6777777671813965,
#     0.33444443345069885,
#     0.8711110949516296,
#     0.5400000214576721]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a foreign object (contamination) inside the neck of the bottle.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.7, 0.3, 1.0, 0.6]'}},
#  {'sample_idx': 42,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "There is a contamination visible inside the glass bottle. It appears as a fuzzy, white shape.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.4, 0.4, 0.6, 0.6]"\n}\n```',
#   'target': [[2.0,
#     0.33888888359069824,
#     0.2822222113609314,
#     0.7233333587646484,
#     0.6222222447395325]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a contamination visible inside the glass bottle. It appears as a fuzzy, white shape.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.4, 0.4, 0.6, 0.6]'}},
#  {'sample_idx': 43,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The bottle has a noticeable broken portion.",\n  "defect_type": "broken",\n  "bounding_box": "[0.7, 0.6, 1, 1]"\n}\n```',
#   'target': [[2.0,
#     0.644444465637207,
#     0.46444445848464966,
#     0.8199999928474426,
#     0.7411110997200012]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle has a noticeable broken portion.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.7, 0.6, 1, 1]'}},
#  {'sample_idx': 44,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "There is a foreign object resembling a string or hair inside the bottle.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.5, 0.2, 0.55, 0.8]"\n}\n```',
#   'target': [[2.0,
#     0.39888888597488403,
#     0.5811111330986023,
#     0.4399999976158142,
#     1.0]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a foreign object resembling a string or hair inside the bottle.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.5, 0.2, 0.55, 0.8]'}},
#  {'sample_idx': 45,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "There is visible contamination inside the bottle.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.4, 0.4, 0.6, 0.6]"\n}\n```',
#   'target': [[2.0,
#     0.27888888120651245,
#     0.3033333420753479,
#     0.7144444584846497,
#     0.7366666793823242]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is visible contamination inside the bottle.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.4, 0.4, 0.6, 0.6]'}},
#  {'sample_idx': 46,
#   'response': '{\n    "is_defective": "yes",\n    "reason": "There is contamination visible on the inner side of the bottle\'s neck.",\n    "defect_type": "contamination",\n    "bounding_box": "[0.3, 0.15, 0.7, 0.85]"\n}',
#   'target': [[2.0,
#     0.28333333134651184,
#     0.2866666615009308,
#     0.7077777981758118,
#     0.7044444680213928]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': "There is contamination visible on the inner side of the bottle's neck.",
#    'defect_type': 'contamination',
#    'bounding_box': '[0.3, 0.15, 0.7, 0.85]'}},
#  {'sample_idx': 47,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "There is a fiber-like contamination inside the bottle.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.4, 0.4, 0.8, 1.0]"\n}\n```',
#   'target': [[2.0,
#     0.5633333325386047,
#     0.3144444525241852,
#     0.8933333158493042,
#     1.0]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a fiber-like contamination inside the bottle.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.4, 0.4, 0.8, 1.0]'}},
#  {'sample_idx': 48,
#   'response': '{\n    "is_defective": "yes",\n    "reason": "There is contamination inside the bottle.",\n    "defect_type": "contamination",\n    "bounding_box": "[0.4, 0.4, 0.6, 0.6]"\n}',
#   'target': [[2.0,
#     0.3933333456516266,
#     0.3355555534362793,
#     0.7155555486679077,
#     0.7477777600288391]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is contamination inside the bottle.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.4, 0.4, 0.6, 0.6]'}},
#  {'sample_idx': 49,
#   'response': '{\n    "is_defective": "yes",\n    "reason": "There is a piece of material inside the bottle, indicating contamination.",\n    "defect_type": "contamination",\n    "bounding_box": "[0.25, 0.2, 0.75, 0.55]"\n}',
#   'target': [[2.0,
#     0.2844444513320923,
#     0.3055555522441864,
#     0.6722221970558167,
#     0.6433333158493042]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a piece of material inside the bottle, indicating contamination.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.25, 0.2, 0.75, 0.55]'}},
#  {'sample_idx': 50,
#   'response': '{\n  "is_defective": "no",\n  "reason": "",\n  "defect_type": "",\n  "bounding_box": ""\n}',
#   'target': [[2.0,
#     0.07333333045244217,
#     0.08444444090127945,
#     0.70333331823349,
#     0.5422222018241882]],
#   'parsed_response': {'is_defective': 'no',
#    'reason': '',
#    'defect_type': '',
#    'bounding_box': ''}},
#  {'sample_idx': 51,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "There is a break on the inner rim of the bottle.",\n  "defect_type": "broken",\n  "bounding_box": "[0.7, 0.6, 1.0, 1.0]"\n}\n```',
#   'target': [[2.0,
#     0.5899999737739563,
#     0.4955555498600006,
#     0.8211110830307007,
#     0.7755555510520935]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a break on the inner rim of the bottle.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.7, 0.6, 1.0, 1.0]'}},
#  {'sample_idx': 52,
#   'response': '{\n  "is_defective": "yes",\n  "reason": "There is a broken section visible near the edge of the bottle.",\n  "defect_type": "broken",\n  "bounding_box": "[0.23, 0.62, 0.42, 0.74]"\n}',
#   'target': [[2.0,
#     0.22333332896232605,
#     0.5666666626930237,
#     0.45222222805023193,
#     0.8022222518920898]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a broken section visible near the edge of the bottle.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.23, 0.62, 0.42, 0.74]'}},
#  {'sample_idx': 53,
#   'response': '```json\n{\n  "is_defective": "no",\n  "reason": "",\n  "defect_type": "",\n  "bounding_box": ""\n}\n```',
#   'target': [[2.0,
#     0.2866666615009308,
#     0.27444443106651306,
#     0.7200000286102295,
#     0.7133333086967468]],
#   'parsed_response': {'is_defective': 'no',
#    'reason': '',
#    'defect_type': '',
#    'bounding_box': ''}},
#  {'sample_idx': 54,
#   'response': '{\n  "is_defective": "yes",\n  "reason": "There is a white string-like foreign object inside the bottle near the bottom edge.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.45, 0.95, 0.55, 1.0]"\n}',
#   'target': [[2.0,
#     0.2822222113609314,
#     0.29777777194976807,
#     0.7255555391311646,
#     0.7355555295944214]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a white string-like foreign object inside the bottle near the bottom edge.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.45, 0.95, 0.55, 1.0]'}},
#  {'sample_idx': 55,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "There appears to be contamination around the inner ring of the bottle.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.1, 0.1, 0.9, 0.9]"\n}\n```',
#   'target': [[2.0,
#     0.0,
#     0.37444445490837097,
#     0.4655555486679077,
#     0.5566666722297668]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There appears to be contamination around the inner ring of the bottle.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.1, 0.1, 0.9, 0.9]'}},
#  {'sample_idx': 56,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The bottle has a broken section on the rim.",\n  "defect_type": "broken",\n  "bounding_box": "[0.09, 0.44, 0.15, 0.50]"\n}\n```',
#   'target': [[2.0,
#     0.2822222113609314,
#     0.29555556178092957,
#     0.7211111187934875,
#     0.7388888597488403]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle has a broken section on the rim.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.09, 0.44, 0.15, 0.50]'}},
#  {'sample_idx': 57,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "There is a contamination in the form of a bubble or particle near the top right edge of the bottle opening.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.65, 0.25, 0.85, 0.35]"\n}\n```',
#   'target': [[2.0,
#     0.26777777075767517,
#     0.27888888120651245,
#     0.7200000286102295,
#     0.7277777791023254],
#    [2.0,
#     0.7200000286102295,
#     0.3722222149372101,
#     0.7833333611488342,
#     0.46222221851348877]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a contamination in the form of a bubble or particle near the top right edge of the bottle opening.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.65, 0.25, 0.85, 0.35]'}},
#  {'sample_idx': 58,
#   'response': '{\n  "is_defective": "yes",\n  "reason": "There is a foreign object inside the bottle indicating contamination.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.3, 0.3, 0.7, 0.7]"\n}',
#   'target': [[2.0,
#     0.2922222316265106,
#     0.301111102104187,
#     0.7211111187934875,
#     0.6766666769981384]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a foreign object inside the bottle indicating contamination.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.3, 0.3, 0.7, 0.7]'}},
#  {'sample_idx': 59,
#   'response': '{\n  "is_defective": "yes",\n  "reason": "There is a visible contamination inside the bottle that appears as a dark spot.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.35, 0.3, 0.45, 0.4]"\n}',
#   'target': [[2.0,
#     0.31555554270744324,
#     0.32111111283302307,
#     0.699999988079071,
#     0.7044444680213928]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a visible contamination inside the bottle that appears as a dark spot.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.35, 0.3, 0.45, 0.4]'}},
#  {'sample_idx': 60,
#   'response': '```json\n{\n  "is_defective": "no",\n  "reason": "",\n  "defect_type": "",\n  "bounding_box": ""\n}\n```',
#   'target': [[2.0,
#     0.34555554389953613,
#     0.550000011920929,
#     0.504444420337677,
#     0.7055555582046509]],
#   'parsed_response': {'is_defective': 'no',
#    'reason': '',
#    'defect_type': '',
#    'bounding_box': ''}},
#  {'sample_idx': 61,
#   'response': '{\n    "is_defective": "yes",\n    "reason": "There is a visible broken section on the upper right part of the bottle opening.",\n    "defect_type": "broken",\n    "bounding_box": "[0.65, 0.15, 0.95, 0.35]"\n}',
#   'target': [[1.0,
#     0.6511111259460449,
#     0.23222222924232483,
#     0.8177777528762817,
#     0.47111111879348755]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a visible broken section on the upper right part of the bottle opening.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.65, 0.15, 0.95, 0.35]'}},
#  {'sample_idx': 62,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "There is a visible broken portion on the bottle.",\n  "defect_type": "broken",\n  "bounding_box": "[0.7, 0.6, 0.9, 0.8]"\n}\n```',
#   'target': [[1.0,
#     0.695555567741394,
#     0.47555556893348694,
#     0.8211110830307007,
#     0.742222249507904]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a visible broken portion on the bottle.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.7, 0.6, 0.9, 0.8]'}},
#  {'sample_idx': 63,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The bottle has contamination on the lower part, visible as a white patch.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.3, 0.7, 0.7, 0.9]"\n}\n```',
#   'target': [[1.0,
#     0.17666666209697723,
#     0.4033333361148834,
#     0.5488888621330261,
#     0.8211110830307007]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle has contamination on the lower part, visible as a white patch.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.3, 0.7, 0.7, 0.9]'}},
#  {'sample_idx': 64,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The glass bottle appears to be broken near the upper right part of the mouth.",\n  "defect_type": "broken",\n  "bounding_box": "[0.75, 0.25, 1.0, 0.5]"\n}\n```',
#   'target': [[1.0,
#     0.5777778029441833,
#     0.23666666448116302,
#     0.7788888812065125,
#     0.44333332777023315]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The glass bottle appears to be broken near the upper right part of the mouth.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.75, 0.25, 1.0, 0.5]'}},
#  {'sample_idx': 65,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "There is visible contamination inside the bottle.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.4, 0.7, 0.6, 1.0]"\n}\n```',
#   'target': [[1.0,
#     0.15555556118488312,
#     0.47555556893348694,
#     0.8133333325386047,
#     0.8388888835906982]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is visible contamination inside the bottle.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.4, 0.7, 0.6, 1.0]'}},
#  {'sample_idx': 66,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "There appears to be a white-colored foreign object/residue inside the bottle neck which indicates contamination.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.1, 0.4, 0.3, 0.6]"\n}\n```',
#   'target': [[1.0,
#     0.185555562376976,
#     0.4566666781902313,
#     0.30444443225860596,
#     0.698888897895813]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There appears to be a white-colored foreign object/residue inside the bottle neck which indicates contamination.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.1, 0.4, 0.3, 0.6]'}},
#  {'sample_idx': 67,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The bottle is broken near the rim.",\n  "defect_type": "broken",\n  "bounding_box": "[0.6, 0.6, 1.0, 1.0]"\n}\n```',
#   'target': [[1.0,
#     0.5155555605888367,
#     0.5,
#     0.8033333420753479,
#     0.8177777528762817]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle is broken near the rim.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.6, 0.6, 1.0, 1.0]'}},
#  {'sample_idx': 68,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "There is a visible broken part inside the bottle.",\n  "defect_type": "broken",\n  "bounding_box": "[0.2, 0.8, 0.5, 1.0]"\n}\n```',
#   'target': [[1.0,
#     0.25111111998558044,
#     0.6844444274902344,
#     0.5166666507720947,
#     0.8322222232818604]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a visible broken part inside the bottle.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.2, 0.8, 0.5, 1.0]'}},
#  {'sample_idx': 69,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "There is a visible broken part of the glass on the right side of the bottle.",\n  "defect_type": "broken",\n  "bounding_box": "[0.6, 0.3, 0.8, 0.5]"\n}\n```',
#   'target': [[1.0,
#     0.7177777886390686,
#     0.3355555534362793,
#     0.8388888835906982,
#     0.6255555748939514]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a visible broken part of the glass on the right side of the bottle.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.6, 0.3, 0.8, 0.5]'}},
#  {'sample_idx': 70,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The bottle has broken glass on the inner rim.",\n  "defect_type": "broken",\n  "bounding_box": "[0.06, 0.06, 0.18, 0.22]"\n}\n```',
#   'target': [[1.0,
#     0.20222222805023193,
#     0.28555554151535034,
#     0.3544444441795349,
#     0.42888888716697693],
#    [1.0,
#     0.20999999344348907,
#     0.4399999976158142,
#     0.23888888955116272,
#     0.4677777886390686],
#    [1.0,
#     0.2644444406032562,
#     0.644444465637207,
#     0.3233333230018616,
#     0.7111111283302307]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle has broken glass on the inner rim.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.06, 0.06, 0.18, 0.22]'}},
#  {'sample_idx': 71,
#   'response': '{\n    "is_defective": "yes",\n    "reason": "There is a visible broken area on the inner edge of the bottle opening.",\n    "defect_type": "broken",\n    "bounding_box": "[0.2, 0.6, 0.35, 0.75]"\n}',
#   'target': [[1.0,
#     0.2199999988079071,
#     0.5844444632530212,
#     0.3266666531562805,
#     0.7077777981758118]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a visible broken area on the inner edge of the bottle opening.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.2, 0.6, 0.35, 0.75]'}},
#  {'sample_idx': 72,
#   'response': '{\n  "is_defective": "yes",\n  "reason": "There appears to be a broken section on the edge of the bottle.",\n  "defect_type": "broken",\n  "bounding_box": "[0.25, 0.1, 0.45, 0.25]"\n}',
#   'target': [[1.0,
#     0.15555556118488312,
#     0.31111112236976624,
#     0.2988888919353485,
#     0.5677777528762817]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There appears to be a broken section on the edge of the bottle.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.25, 0.1, 0.45, 0.25]'}},
#  {'sample_idx': 73,
#   'response': '{\n  "is_defective": "yes",\n  "reason": "The bottle has a broken section on the left side of the rim.",\n  "defect_type": "broken",\n  "bounding_box": "[0.1, 0.3, 0.35, 0.5]"\n}',
#   'target': [[1.0,
#     0.1899999976158142,
#     0.4933333396911621,
#     0.3822222352027893,
#     0.7988888621330261]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle has a broken section on the left side of the rim.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.1, 0.3, 0.35, 0.5]'}},
#  {'sample_idx': 74,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The bottle has a visible broken section on the inner rim.",\n  "defect_type": "broken",\n  "bounding_box": "[0.25, 0.65, 0.45, 0.80]"\n}\n```',
#   'target': [[1.0,
#     0.33222222328186035,
#     0.19333332777023315,
#     0.37444445490837097,
#     0.2666666805744171],
#    [1.0,
#     0.1944444477558136,
#     0.5588889122009277,
#     0.4233333468437195,
#     0.804444432258606]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle has a visible broken section on the inner rim.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.25, 0.65, 0.45, 0.80]'}},
#  {'sample_idx': 75,
#   'response': '{\n  "is_defective": "yes",\n  "reason": "There is a section of the glass that appears to be broken or chipped.",\n  "defect_type": "broken",\n  "bounding_box": "[0.2, 0.2, 0.4, 0.4]"\n}',
#   'target': [[1.0,
#     0.1733333319425583,
#     0.4322222173213959,
#     0.29555556178092957,
#     0.7144444584846497],
#    [1.0,
#     0.7288888692855835,
#     0.7188888788223267,
#     0.7566666603088379,
#     0.7444444298744202]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a section of the glass that appears to be broken or chipped.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.2, 0.2, 0.4, 0.4]'}},
#  {'sample_idx': 76,
#   'response': '{\n  "is_defective": "yes",\n  "reason": "The bottle has a broken section at the bottom area and apparent white contaminants.",\n  "defect_type": "broken",\n  "bounding_box": "[0.3, 0.7, 0.7, 1.0]"\n}',
#   'target': [[1.0,
#     0.20777778327465057,
#     0.5644444227218628,
#     0.8255555629730225,
#     0.8433333039283752]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle has a broken section at the bottom area and apparent white contaminants.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.3, 0.7, 0.7, 1.0]'}},
#  {'sample_idx': 77,
#   'response': '{\n  "is_defective": "yes",\n  "reason": "The glass bottle has a chipped/broken area on the inner rim.",\n  "defect_type": "broken",\n  "bounding_box": "[0.52, 0.1, 0.64, 0.24]"\n}',
#   'target': [[1.0,
#     0.504444420337677,
#     0.15333333611488342,
#     0.8355555534362793,
#     0.3777777850627899]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The glass bottle has a chipped/broken area on the inner rim.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.52, 0.1, 0.64, 0.24]'}},
#  {'sample_idx': 78,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "There is a broken area on the rim of the bottle",\n  "defect_type": "broken",\n  "bounding_box": "[0.4, 0.05, 0.6, 0.2]"\n}\n```',
#   'target': [[1.0,
#     0.39222222566604614,
#     0.1666666716337204,
#     0.7133333086967468,
#     0.30000001192092896]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a broken area on the rim of the bottle',
#    'defect_type': 'broken',
#    'bounding_box': '[0.4, 0.05, 0.6, 0.2]'}},
#  {'sample_idx': 79,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "The bottle has broken sections around the rim.",\n  "defect_type": "broken",\n  "bounding_box": "[0.3, 0.7, 0.7, 0.9]"\n}\n```',
#   'target': [[1.0,
#     0.4955555498600006,
#     0.6177777647972107,
#     0.7566666603088379,
#     0.8188889026641846]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'The bottle has broken sections around the rim.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.3, 0.7, 0.7, 0.9]'}},
#  {'sample_idx': 80,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "There is a visible broken piece inside the glass bottle near the bottom edge.",\n  "defect_type": "broken",\n  "bounding_box": "[0.25, 0.75, 0.45, 0.95]"\n}\n```',
#   'target': [[1.0,
#     0.24111111462116241,
#     0.6588888764381409,
#     0.44555556774139404,
#     0.8199999928474426]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a visible broken piece inside the glass bottle near the bottom edge.',
#    'defect_type': 'broken',
#    'bounding_box': '[0.25, 0.75, 0.45, 0.95]'}},
#  {'sample_idx': 81,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "There is a noticeable contamination around the rim of the bottle.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.6, 0.1, 1.0, 0.4]"\n}\n```',
#   'target': [[1.0,
#     0.5099999904632568,
#     0.18111111223697662,
#     0.8211110830307007,
#     0.6066666841506958]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a noticeable contamination around the rim of the bottle.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.6, 0.1, 1.0, 0.4]'}},
#  {'sample_idx': 82,
#   'response': '```json\n{\n  "is_defective": "yes",\n  "reason": "There is a visible contamination on the inner rim of the bottle.",\n  "defect_type": "contamination",\n  "bounding_box": "[0.7, 0.3, 1.0, 0.5]"\n}\n```',
#   'target': [[1.0,
#     0.601111114025116,
#     0.21444444358348846,
#     0.8355555534362793,
#     0.5344444513320923]],
#   'parsed_response': {'is_defective': 'yes',
#    'reason': 'There is a visible contamination on the inner rim of the bottle.',
#    'defect_type': 'contamination',
#    'bounding_box': '[0.7, 0.3, 1.0, 0.5]'}}]

# %%
# Calculate multiclass accuracy - transistor

good = 0
broken_or_misplaced_lead = 0
misplaced_transistor = 0
damaged_casing = 0

for result in results:
    defect_type = result["parsed_response"]["defect_type"]
    # print(defect_type)
    target = result["target"][0][0]
    # print(target)
    
    if defect_type == "" and target == 0:
        good += 1
    elif defect_type in ["broken_or_misplaced lead", "broken_or_misplaced_lead" ] and (target == 1):
        broken_or_misplaced_lead += 1
    elif defect_type == "misplaced transistor" and target == 2:
        misplaced_transistor += 1
    elif defect_type == "damaged casing" and target == 3:
        damaged_casing += 1
        
    
    
print(good, broken_or_misplaced_lead, misplaced_transistor, damaged_casing)
print((good + broken_or_misplaced_lead + misplaced_transistor + damaged_casing) / len(results))
# Out:
# 19 0 0 0
# 0.11875

# %%
# # Calculate multiclass accuracy - screw

good = 0
damaged_head = 0
damaged_shank = 0
damaged_thread = 0
damaged_tip = 0

for result in results:
    defect_type = result["parsed_response"]["defect_type"]
    # print(defect_type)
    defect_types = [defect_type.split(", ")]
    # print(defect_types)
    target = result["target"][0][0]
    # print(target)
    
    # print(defect_types, target)
    
    for defect_type in defect_types[0]:
        if defect_type == "" and target == 0:
            good += 1
        elif defect_type == "damaged head" and (target == 1):
            damaged_head += 1
        elif defect_type == "damaged shank" and target == 2:
            damaged_shank += 1
        elif defect_type in [ "damaged thread", "damaged-thread" ] and target == 3:
            damaged_thread += 1
        elif defect_type == "damaged tip" and target == 4:
            damaged_tip += 1
        
    
    
print(good, damaged_head, damaged_shank, damaged_thread, damaged_tip)
print((good + damaged_head + damaged_shank + damaged_thread + damaged_tip) / len(results))
# Out:
# 19 18 22 33 23
# 0.71875

# %%
# # Calculate multiclass accuracy - bottle

good = 0
broken = 0
contamination = 0

for result in results:
    defect_type = result["parsed_response"]["defect_type"]
    # print(defect_type)
    defect_types = [defect_type.split(", ")]
    # print(defect_types)
    target = result["target"][0][0]
    
    for defect_type in defect_types[0]:
        if defect_type == "" and target == 0:
            good += 1
        elif defect_type == "broken" and (target == 1):
            broken += 1
        elif defect_type == "contamination" and target == 2:
            contamination += 1
        
print(good, broken, contamination)
print((good + broken + contamination) / len(results))
# Out:
# 6 33 14
# 0.6385542168674698

# %%
# # Calculate multiclass accuracy - metal_plate

good = 0
rusting = 0
scratches = 0

for result in results:
    defect_type = result["parsed_response"]["defect_type"]
    # print(defect_type)
    defect_types = [defect_type.split(", ")]
    # print(defect_types)
    target = result["target"][0][0]
   
    
    for defect_type in defect_types[0]:
        if defect_type == "" and target == 0:
            good += 1
        elif defect_type == "rusting" and (target == 1):
            rusting += 1
        elif defect_type == "scratches" and target == 2:
            scratches += 1
        
print(good, rusting, scratches)
print((good + rusting + scratches) / len(results))
# Out:
# 19 0 0
# 0.11875
